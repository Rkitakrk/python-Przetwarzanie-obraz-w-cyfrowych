# %%
from skimage import data

im = data.chelsea()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.imshow(im, cmap="gray")
plt.axis('off')
plt.show()

# %%
print(im.shape, im.dtype)
# Out:
# (300, 451, 3) uint8

# %%
print(im[:5,:5])
# Out:
# [[[143 120 104]
#   [143 120 104]
#   [141 118 102]
#   [141 118 102]
#   [141 118 102]]
#
#  [[146 123 107]
#   [145 122 106]
#   [143 120 104]
#   [142 119 103]
#   [142 119 103]]
#
#  [[148 126 112]
#   [147 125 111]
#   [146 122 109]
#   [145 121 108]
#   [145 122 106]]
#
#  [[151 129 116]
#   [149 127 114]
#   [147 125 112]
#   [147 125 112]
#   [146 124 110]]
#
#  [[153 131 120]
#   [151 129 118]
#   [150 128 115]
#   [149 127 114]
#   [148 126 112]]]

# %%
from skimage.color import convert_colorspace, rgb2lab, rgb2hsv, rgb2gray

imHSV = rgb2hsv(im)
# Out:
# d:\Anaconda\envs\py36\lib\site-packages\skimage\color\colorconv.py:274: RuntimeWarning: divide by zero encountered in true_divide
#   out[idx, 0] = (arr[idx, 1] - arr[idx, 2]) / delta[idx]

# %%
print(imHSV.shape, imHSV.dtype)
# Out:
# (300, 451, 3) float64

# %%
print(imHSV[:3,:3])
# Out:
# [[[0.06837607 0.27272727 0.56078431]
#   [0.06837607 0.27272727 0.56078431]
#   [0.06837607 0.27659574 0.55294118]]
#
#  [[0.06837607 0.26712329 0.57254902]
#   [0.06837607 0.26896552 0.56862745]
#   [0.06837607 0.27272727 0.56078431]]
#
#  [[0.06481481 0.24324324 0.58039216]
#   [0.06481481 0.24489796 0.57647059]
#   [0.05855856 0.25342466 0.57254902]]]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.imshow(imHSV, cmap="gray")
plt.axis('off')
plt.show()

# %%
imLab = rgb2lab(im)

print(imLab.shape, imLab.dtype)
# Out:
# (300, 451, 3) float64

# %%
print(imLab[:3, :3])
# Out:
# [[[52.14428353  6.33656553 12.11784839]
#   [52.14428353  6.33656553 12.11784839]
#   [51.35858721  6.36701805 12.15812384]]
#
#  [[53.31878932  6.29217457 12.05885627]
#   [52.9278203   6.30680413 12.07833506]
#   [52.14428353  6.33656553 12.11784839]]
#
#  [[54.4365192   6.14673595 10.75751805]
#   [54.04687273  6.15994475 10.77455296]
#   [53.09690035  7.16855355 10.58575968]]]

# %%
print(imLab.min())
# Out:
# -24.971744792775308

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.imshow(imLab, cmap="gray")
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
